# %%
print("This is JupyterLab Demo file")
# Out:
# This is JupyterLab Demo file

# %%
print("This is updated version of the jupyter notebook")
# Out:
# This is updated version of the jupyter notebook
