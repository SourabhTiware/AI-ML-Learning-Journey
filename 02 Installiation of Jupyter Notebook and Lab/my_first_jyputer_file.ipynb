# %% [markdown]
# # This is demo file for Jupyter Notebook
# ## This file only for learning purpose

# %%
print("Prime AI-ML batch")
# Out:
# Prime AI-ML batch

# %%
print("This is demo of the jupyter Notebook")
# Out:
# This is demo of the jupyter Notebook

# %%
print("In this lecture learn about the jupyter notebook. How to familiar with jupyter notebook")
# Out:
# In this lecture learn about the jupyter notebook. How to familiar with jupyter notebook
