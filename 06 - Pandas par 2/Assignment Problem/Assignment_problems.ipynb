# %% [markdown]
# ## Q1 - Start by the following IRIS dataset

# %%
import numpy as np
import pandas as pd

# %%
df_flower = pd.read_csv("IRIS.csv")

# %%
# Display the following information 
# 1. first 10 rows
# 2. shape & Data types
# 3. summary statistics (mean,std,max,min))

# %%
df2 = df_flower.copy()

# %%
# 1. fist 10 rows
df2.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
# shape & Data types

df2.shape
# Out:
# (150, 5)

# %%
df2.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# 3 summary statistics (mean,std,max,min))

# %%
df2.groupby("species")["sepal_length"].agg(avg_sepal_len_mean = "mean", avg_sepal_len_max = "max", avg_sepal_len_min = "min", avg_sepal_len_std = "std")
# Out:
#                  avg_sepal_len_mean  avg_sepal_len_max  avg_sepal_len_min  \
# species
# Iris-setosa                   5.006                5.8                4.3
# Iris-versicolor               5.936                7.0                4.9
# Iris-virginica                6.588                7.9                4.9
#
#                  avg_sepal_len_std
# species
# Iris-setosa               0.352490
# Iris-versicolor           0.516171
# Iris-virginica            0.635880

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# B- Select only those rows where:
# petal_length > 4.5
# species = "iris-virginica"

# %%
df_b = df_flower.copy()

# %%
# petal_length > 4.5
df_b.query("petal_length > 4.5")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 58            6.6          2.9           4.6          1.3  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [63 rows x 5 columns]

# %%
# species = "iris-virginica"

virginica_only = df_b[df_b['species'] == "Iris-virginica"]
virginica_only
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# ...

# %%
# Group by species and compute
# 1 Average sepal_length
# 2 Maximum petal_width
# 3 Standard deviation of sepal_width

df_b.groupby("species").agg(
    avg_sepal_len=("sepal_length", "mean"),
    max_petal_wid =("petal_width","max"),
    std_sepal_wid = ("petal_width","std")
)
# Out:
#                  avg_sepal_len  max_petal_wid  std_sepal_wid
# species
# Iris-setosa              5.006            0.6       0.107210
# Iris-versicolor          5.936            1.8       0.197753
# Iris-virginica           6.588            2.5       0.274650

# %%
# d create a new column "petal_ratio" = petal_length / petal_width
# for each species, find the averate petal_ratio

# %%
df_b["petal_ratio"] = df_b["petal_length"] / df_b["petal_width"]

# %%
df_b
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# ...

# %% [markdown]
# ## Q- 2 - Start by loading the TITANIC data set

# %%
df_titanic = pd.read_csv("Titanic-Dataset.csv")
df_a = df_titanic.copy()

# %%
# A - Display only columns. Name, Sex, Age, Fare, Survived
df_a[["Name", "Sex", "Age", "Fare", "Survived"] ]
# Out:
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ..                                                 ...     ...   ...      ...
# 886                              Montvila, Rev. Juozas    male  27.0  13.0000
# 887                       Graham, Miss. Margaret Edith  female  19.0  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN  23.4500
# 889                              Behr, Mr. Karl Howell    male  26.0  30.0000
# 890                                Dooley, Mr. Patrick    male  32.0   7.7500
#
#      Survived
# 0           0
# ...

# %%
# B = Select Passengers Who:
# Are femare
# Fare > 30
df_b = df_titanic.copy()
B = df_b.query("Sex == 'female' and Fare > 30")
B
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 25            26         1       3
# 31            32         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_c = df_titanic.copy()

# %%
# Group by Pclass and compute:
# Survival rate
# Averate Fare
# Average Age

df_c.groupby("Name").agg(
    survival_rate=("Survived", "mean"),
    average_fare=("Fare", "mean"),
    average_age=("Age", "mean")
)
# Out:
#                                        survival_rate  average_fare  \
# Name
# Abbing, Mr. Anthony                              0.0        7.5500
# Abbott, Mr. Rossmore Edward                      0.0       20.2500
# Abbott, Mrs. Stanton (Rosa Hunt)                 1.0       20.2500
# Abelson, Mr. Samuel                              0.0       24.0000
# Abelson, Mrs. Samuel (Hannah Wizosky)            1.0       24.0000
# ...                                              ...           ...
# de Mulder, Mr. Theodore                          1.0        9.5000
# de Pelsmaeker, Mr. Alfons                        0.0        9.5000
# del Carlo, Mr. Sebastiano                        0.0       27.7208
# van Billiard, Mr. Austin Blyler                  0.0       14.5000
# van Melkebeke, Mr. Philemon                      0.0        9.5000
#
#                                        average_age
# Name
# Abbing, Mr. Anthony                           42.0
# ...

# %%
df_c
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
